# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import re

#from goog_api import google_api_key
#import googlemaps
#gmaps = googlemaps.Client(key=google_api_key)

# %%
# import data
#glob_name = "yelp_academic_dataset_" + local_dat_name + '.json' # business, checkin, user, review, tip
def glob_name(name):
    return "yelp_academic_dataset_" + name + ".json"

business_data = pd.read_json(os.path.join(os.getcwd(), 'data', glob_name('business')), lines=True)
review_data = pd.read_json(os.path.join(os.getcwd(), 'data', glob_name('review')), lines=True)
#df = pd.Dataframe.from_dict()
df = pd.DataFrame.from_dict(business_data)

# %%
# filter by state, and by food.
user_state = 'CA'

df = df.loc[df['state'] == user_state]
df = df.loc[df['categories'].str.contains("food|restaurant", na=False, flags=re.IGNORECASE, regex=True)]

# %%
# filter categories by the user's food preference
#df.head()
user_prefs = ['Vegan']
user_prefs = "|".join(user_prefs)
df = df.loc[df['categories'].str.contains(user_prefs, na=False, flags=re.IGNORECASE, regex=True)]
df.head()
# Out:
#                   business_id                         name  \
# 921    vLT1KtrA9bWvjFOg-0xVIg            Pieology Pizzeria
# 6300   iHdrLu8deF5GceB0V1rPhA                     Oliver's
# 18784  Js3m_GdqNUGnEgXJ8WMtfQ                 Hana Kitchen
# 19072  GBD-YjcOD1nG0wv4L0Lvfg                Venus in Furs
# 20444  Ksz_jsyyK3Zjlq_Cz81ZBA  Adama Vegan Comfort Cuisine
#
#                          address           city state postal_code   latitude  \
# 921    7000 Hollister Ave, Ste F         Goleta    CA       93117  34.430453
# 6300       1198 Coast Village Rd  Santa Barbara    CA       93108  34.421334
# 18784               503 State St  Santa Barbara    CA       93101  34.416504
# 19072               18 E Cota St  Santa Barbara    CA       93101  34.418217
# 20444             428 Chapala St  Santa Barbara    CA       93101  34.415688
#
#         longitude  stars  review_count  is_open  \
# 921   -119.872345    3.5           131        0
# 6300  -119.644981    4.5           313        1
# 18784 -119.695618    3.0           253        1
# 19072 -119.696120    5.0            24        1
# 20444 -119.696007    4.0           238        0
#
#                                               attributes  \
# 921    {'RestaurantsAttire': ''casual'', 'Alcohol': '...
# 6300   {'RestaurantsAttire': 'u'dressy'', 'BikeParkin...
# 18784  {'RestaurantsDelivery': 'True', 'DogsAllowed':...
# 19072  {'BusinessParking': '{'garage': False, 'street...
# 20444  {'RestaurantsAttire': 'u'casual'', 'Restaurant...
#
#                                               categories  \
# 921    Restaurants, Gluten-Free, Pizza, Vegan, Fast Food
# 6300          American (Traditional), Vegan, Restaurants
# 18784  Bubble Tea, Restaurants, Food, Asian Fusion, V...
# 19072  American (Traditional), Restaurants, Wine Bars...
# 20444                     Restaurants, Vegetarian, Vegan
#
#                                                    hours  new_rating
# 921    {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...    3.466418
# 6300   {'Tuesday': '17:0-21:0', 'Wednesday': '17:0-21...    4.476266
# 18784  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...    2.988281
# 19072  {'Wednesday': '16:0-22:0', 'Thursday': '16:0-2...    4.666667
# 20444  {'Monday': '17:0-21:0', 'Tuesday': '17:0-21:0'...    3.975104

# %%
# small utility that writes out all possible categories to a txt file.
# used by chatting system.
x = list(df['categories'].str.split(', '))
categories = []
for lst in x:
    for i in lst:
        if i not in categories:
            categories.append(i)
with open('categories.txt', 'w') as f:
    f.write('\n'.join(categories))

# %%
# drop the unused columns
new_df = df[['name','latitude','longitude','categories','stars', 'review_count']].copy()
# Out:
#                               name   latitude   longitude  \
# 921              Pieology Pizzeria  34.430453 -119.872345
# 6300                      Oliver's  34.421334 -119.644981
# 18784                 Hana Kitchen  34.416504 -119.695618
# 19072                Venus in Furs  34.418217 -119.696120
# 20444  Adama Vegan Comfort Cuisine  34.415688 -119.696007
#
#                                               categories  stars  review_count  \
# 921    Restaurants, Gluten-Free, Pizza, Vegan, Fast Food    3.5           131
# 6300          American (Traditional), Vegan, Restaurants    4.5           313
# 18784  Bubble Tea, Restaurants, Food, Asian Fusion, V...    3.0           253
# 19072  American (Traditional), Restaurants, Wine Bars...    5.0            24
# 20444                     Restaurants, Vegetarian, Vegan    4.0           238
#
#        new_rating
# 921      3.466418
# 6300     4.476266
# 18784    2.988281
# 19072    4.666667
# 20444    3.975104

# %%
# create a new rating column based on the baye's prob of stars and review count.
def set_bayes(R, W):
    def bayesian_probability(rating, review_count):
        return (W*R + review_count * rating) / (W + review_count)
    return baye_prob

bayes_prob = set_bayes(2, 3)

new_df['new_rating'] = df.apply(lambda row: bayes_prob(row['stars'], row['review_count']), axis=1)
new_df.sort_values('new_rating', ascending=False)
new_df.to_json('latlon.json',orient="records", lines=True)
# Out:
#                                                  name   latitude   longitude  \
# 150169                                     Oat Bakery  34.416548 -119.695626
# 19072                                   Venus in Furs  34.418217 -119.696120
# 145143                                     Mesa Verde  34.401348 -119.723080
# 127157                                    Green Table  34.417872 -119.700702
# 6300                                         Oliver's  34.421334 -119.644981
# 55593                             Apna Indian Kitchen  34.419239 -119.698387
# 50521                                     The Honey B  34.419336 -119.695822
# 94492                                       Embermill  34.422053 -119.703135
# 41668                                       Satellite  34.422616 -119.704029
# 78005                                         Pressed  34.418992 -119.700057
# 94858   Modern Times Academy of Recreational Sciences  34.416541 -119.694576
# 80801                                        Fala Bar  34.423608 -119.707054
# 112430                           Modern Times Kitchen  34.416536 -119.694577
# 105629                                        Pressed  34.422759 -119.651859
# 133712                            Rascal's Vegan Food  34.418217 -119.696120
# 64216                                       Taco Tuyo  34.420334 -119.710749
# 94723                                 Flavor of India  34.440613 -119.729371
# 119513                                 Sojourner Cafe  34.422437 -119.698402
# 127500                                  Vegan GreenGO  34.440123 -119.740862
# 145557                    Masala Spice Indian Cuisine  34.441667 -119.825761
# 20444                     Adama Vegan Comfort Cuisine  34.415688 -119.696007
# 96266                                            Nook  34.415733 -119.688461
# 71952                                      Mesa Pizza  34.400576 -119.722718
# 95745                                     Ike's Place  34.411881 -119.854975
# 107419               Sharky's Woodfired Mexican Grill  34.431177 -119.874063
# 127682                        Ike’s Love & Sandwiches  34.430741 -119.714266
# 135867                                       Caruso's  34.420532 -119.628116
# 88786                            Alchemy Wellness Spa  34.415801 -119.696462
# 145608                              Spiritland Bistro  34.427135 -119.702428
# 54451                             Santa Barbara Hives  34.393343 -119.519110
# 921                                 Pieology Pizzeria  34.430453 -119.872345
# 117365                                    Juice Ranch  34.420782 -119.644921
# 107097                                   Hana Kitchen  34.413252 -119.856465
# 18784                                    Hana Kitchen  34.416504 -119.695618
# 143555                        Chamomile Cafe & Bakery  34.398644 -119.519186
#
#                                                categories  stars  \
# 150169  Bakeries, Vegan, Specialty Food, Food Delivery...    5.0
# 19072   American (Traditional), Restaurants, Wine Bars...    5.0
# 145143  Garage Door Services, Restaurants, Live/Raw Fo...    4.5
# 127157  Juice Bars & Smoothies, Restaurants, Food, Veg...    4.5
# 6300           American (Traditional), Vegan, Restaurants    4.5
# 55593   Gluten-Free, Gastropubs, Vegan, Restaurants, I...    4.5
# 50521   Vegetarian, Gluten-Free, Food, Restaurants, Co...    4.5
# 94492   Caribbean, Restaurants, Gluten-Free, Cajun/Cre...    4.5
# 41668   Restaurants, Vegan, Tapas/Small Plates, Vegeta...    4.5
# 78005   Ice Cream & Frozen Yogurt, Juice Bars & Smooth...    4.5
# 94858   Beer Bar, Breakfast & Brunch, Vegan, Bars, Nig...    4.5
# 80801   Restaurants, Vegan, Gluten-Free, Falafel, Medi...    4.5
# 112430                 Vegan, American (New), Restaurants    4.5
# 105629  Specialty Food, Convenience Stores, Juice Bars...    4.5
# 133712                                 Restaurants, Vegan    4.5
# 64216   Food Trucks, Food, Food Delivery Services, Tac...    4.5
# 94723   Pakistani, Restaurants, Buffets, Seafood, Hala...    4.0
# 119513  Sandwiches, Vegan, Cafes, Vegetarian, Restaurants    4.0
# 127500            Mexican, Vegan, Restaurants, Vegetarian    4.0
# 145557             Vegan, Vegetarian, Restaurants, Indian    4.0
# 20444                      Restaurants, Vegetarian, Vegan    4.0
# 96266   Soul Food, Wine Tasting Room, Food, Restaurant...    4.0
# 71952   Pizza, Restaurants, Italian, Vegan, Gluten-Fre...    4.0
# 95745   Restaurants, Sandwiches, Vegan, Delis, Gluten-...    4.0
# 107419  Mexican, Restaurants, Food, Organic Stores, Ca...    4.0
# 127682         Vegan, Vegetarian, Sandwiches, Restaurants    4.0
# 135867                        Vegan, Restaurants, Italian    4.0
# 88786   Skin Care, Cafes, Fitness & Instruction, Vegan...    4.0
# 145608  Restaurants, Vegetarian, French, Vegan, Seafoo...    4.0
# 54451   Cheese Shops, Food, Arts & Crafts, Home Decor,...    5.0
# 921     Restaurants, Gluten-Free, Pizza, Vegan, Fast Food    3.5
# 117365  Restaurants, Food, Live/Raw Food, Juice Bars &...    3.5
# 107097  Vegan, Asian Fusion, Bubble Tea, Restaurants, ...    3.0
# 18784   Bubble Tea, Restaurants, Food, Asian Fusion, V...    3.0
# 143555  Food, Bakeries, Restaurants, Vegan, American (...    3.0
#
#         review_count  new_rating
# 150169           123    4.928571
# 19072             24    4.666667
# 145143          1796    4.495831
# 127157           319    4.476708
# 6300             313    4.476266
# 55593            246    4.469880
# 50521            215    4.465596
# 94492            211    4.464953
# 41668            159    4.453704
# 78005            111    4.434211
# 94858             74    4.402597
# 80801             70    4.397260
# 112430            54    4.368421
# 105629            28    4.258065
# 133712            25    4.232143
# 64216             13    4.031250
# 94723            501    3.988095
# 119513           276    3.978495
# 127500           273    3.978261
# 145557           245    3.975806
# 20444            238    3.975104
# 96266            208    3.971564
# 71952            176    3.966480
# 95745            161    3.963415
# 107419           103    3.943396
# 127682            97    3.940000
# 135867            88    3.934066
# 88786             58    3.901639
# 145608            51    3.888889
# 54451              5    3.875000
# 921              131    3.466418
# 117365            21    3.312500
# 107097           328    2.990937
# 18784            253    2.988281
# 143555            12    2.800000

# %%
with open(, 'w') as f:
